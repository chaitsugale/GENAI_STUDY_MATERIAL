# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitsugale/GENAI_STUDY_MATERIAL/blob/main/word_2_vec_genai_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
import pandas as pd
import numpy as np
import nltk

# %%
from nltk import sent_tokenize,word_tokenize

# %%
from nltk.corpus import stopwords

# %%
from gensim.utils import simple_preprocess

# %%
dir = "/content/data"

# %%
dir
# Out:
# '/content/data'

# %%
filename = '004ssb.txt'

# %%
os.path.join(dir,filename)
# Out:
# '/content/data/004ssb.txt'

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
stop_words = stopwords.words("english")

# %%
def preprocess(sent):
  words=word_tokenize(sent)
  words=[word for word in words if word not in stop_words]
  sent=" ".join(words)
  return sent

# %%
story=[]
for filename in os.listdir(dir):
  f=open(os.path.join(dir,filename),mode = "r",encoding = "latin-1")
  corpus=f.read()
  sents=sent_tokenize(corpus)
  for sent in sents:
    sent=preprocess(sent)
    story.append(simple_preprocess(sent)) #document into a list of tokens.

# %%
story
# Out:
# [['version',
#   'history',
#   'reedited',
#   'maelstrom',
#   'feast',
#   'for',
#   'crows',
#   'book',
#   'four',
#   'song',
#   'ice',
#   'fire',
#   'george'],
#  ['martin', 'prologue', 'dragons', 'said', 'mollander'],
#  ['he', 'snatched', 'withered', 'apple', 'ground', 'tossed', 'hand', 'hand'],
#  ['throw', 'apple', 'urged', 'alleras', 'sphinx'],
#  ['he', 'slipped', 'arrow', 'quiver', 'nocked', 'bowstring'],
#  ['like',
#   'see',
#   'dragon',
#   'roone',
#   'youngest',
#   'chunky',
#   'boy',
#   'still',
#   'two',
#   'years',
#   'shy',
#   'manhood'],
#  ['like',
#   'much',
#   'and',
#   'like',
#   'sleep',
#   'rosey',
#   'arms',
#   'around',
#   'pate',
#   'thought'],
#  ['he', 'shifted', 'restlessly', 'bench'],
#  ['by', 'morrow', 'girl', 'could', 'well'],
#  ['take',
#   'far',
#   'oldtown',
#   'across',
#   'narrow',
#   'sea',
#   'one',
#   'free',
#   'cities'],
#  ['there', 'maesters', 'one', 'accuse'],
#  ['he',
#   'could',
#   'hear',
# ...
